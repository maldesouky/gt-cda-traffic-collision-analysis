# %%
## ISyE6740 - Computational Data Analytics
## Course Project
## Data Preparation - Stage 1
##
## -  This script reads datasets from CSV files, then saves them to
##    parquet files for speed.
## -  It is also responsible for creating a data sample for visualization
##    setup, because Tableau is so slow with original data.
## -  Metadata for all datasets is loaded and some statistics to aid in
##    later tasks are generated.
## -  Data reduction is performed to reduce number of features available
##    for analysis stage. At this stage, mostly useless features are removed.

# %%
## imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import os
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
## PART 1
## Convert CSV to Parquet files, if Parquet files do not exist
data_files = pd.DataFrame.from_dict({
    'tableName': ['CRASHES',
                  'VEHICLES',
                  'PEOPLE'],
    'csv_file': [r'.\data\csv\chicago-crashes-20240416.csv',
                 r'.\data\csv\chicago-vehicles-20240416.csv',
                 r'.\data\csv\chicago-people-20240416.csv'],
    'metadata_file': [r'.\data\metadata\chicago-crashes-20240416.json',
                      r'.\data\metadata\chicago-vehicles-20240416.json',
                      r'.\data\metadata\chicago-people-20240416.json'],
    'csv_sample_file': [r'.\data\sample\chicago-crashes-sample.csv',
                        r'.\data\sample\chicago-vehicles-sample.csv',
                        r'.\data\sample\chicago-people-sample.csv'],
    'parquet_file': [r'.\data\parquet\chicago-crashes-20240416.parquet.gzip',
                     r'.\data\parquet\chicago-vehicles-20240416.parquet.gzip',
                     r'.\data\parquet\chicago-people-20240416.parquet.gzip'],
    'reduced_st1': [r'.\data\reduced\stage1\chicago-crashes-reduced-st1.parquet.gzip',
                    r'.\data\reduced\stage1\chicago-vehicles-reduced-st1.parquet.gzip',
                    r'.\data\reduced\stage1\chicago-people-reduced-st1.parquet.gzip']
})

for _, r in data_files.iterrows():
    if not os.path.isfile(r['parquet_file']):
        print(f"NOT FOUND: {r['parquet_file']}.\nCREATING: {r['parquet_file']}...", end="")
        df = pd.read_csv(r['csv_file'], low_memory=False)
        df.to_parquet(r['parquet_file'], index=False, compression='gzip', engine='auto')
        print("DONE!\n")
    else:
        print(f"FOUND: {r['parquet_file']}.\nMoving on...\n")

print("Conversion complete!")
# Out:
# FOUND: .\data\parquet\chicago-crashes-20240416.parquet.gzip.
# Moving on...
#
# FOUND: .\data\parquet\chicago-vehicles-20240416.parquet.gzip.
# Moving on...
#
# FOUND: .\data\parquet\chicago-people-20240416.parquet.gzip.
# Moving on...
#
# Conversion complete!

# %%
## PART 2
## Load Metadata
metadata_df = pd.DataFrame(columns=['tableName', 'name', 'dataTypeName', 'description'])

for _, r in data_files.iterrows():
    with open(r['metadata_file'], errors='ignore') as f:
        metadata_dict = json.load(f)
        df = pd.DataFrame(metadata_dict['columns'])[['name', 'dataTypeName', 'description']]
        df.insert(loc=0, column='tableName', value=r['tableName'])
        
        metadata_df = pd.concat([metadata_df, df])

metadata_df = metadata_df.reset_index(drop=False, names='column_index') \
                [['tableName', 'column_index', 'name', 'dataTypeName', 'description']]

metadata_df.insert(loc=4, column='count', value=0)
metadata_df['count'] = metadata_df['count'].astype(int)

metadata_df.insert(loc=5, column='nulls', value=0)
metadata_df['count'] = metadata_df['nulls'].astype(int)

metadata_df.insert(loc=6, column='unique', value=0)
metadata_df['count'] = metadata_df['unique'].astype(int)

print('Metadata loaded successfully...')
# metadata_df
# Out:
# Metadata loaded successfully...

# %%
## PART 3
## Load Data from Parquet Files
## Update data statistics
data_frames={}
for _, r in data_files.iterrows():
    print(f"PROCESSING: {r['tableName']}...")
    df = pd.read_parquet(r['parquet_file'], engine='auto').fillna(value=np.nan)

    # count
    metadata_df.loc[metadata_df['tableName']==r['tableName'], 'count']=df.shape[0]

    # nulls
    df_nulls = pd.DataFrame(df.isnull().sum(), columns=['nulls']).reset_index(drop=False, names='name')
    df_nulls['tableName'] = r['tableName']
    metadata_df = pd.merge(left=metadata_df, right=df_nulls, how='left', suffixes=['', '_'], on=('tableName', 'name')).ffill()
    metadata_df.loc[metadata_df['tableName']==r['tableName'], 'nulls'] = metadata_df.loc[metadata_df['tableName']==r['tableName'], 'nulls_'].fillna(0).astype(int)
    # metadata_df.update(df_nulls)

    # unique elements
    df_unique =pd.DataFrame(df.nunique(), columns=['unique']).reset_index(drop=False, names='name')
    df_unique['tableName'] = r['tableName']
    metadata_df = pd.merge(left=metadata_df, right=df_unique, how='left', suffixes=['', '_'], on=('tableName', 'name')).ffill()
    metadata_df.loc[metadata_df['tableName']==r['tableName'], 'unique'] = metadata_df.loc[metadata_df['tableName']==r['tableName'], 'unique_'].fillna(0).astype(int)
    # metadata_df['unique'] = metadata_df['unique_'].fillna(0).astype(int)

    metadata_df = metadata_df.drop(['nulls_', 'unique_'], axis=1)
    # metadata_df.update(df_unique)    

    data_frames[r['tableName']] = df.copy()

# Add new statistics
metadata_df.insert(loc=7, column='percent_null', value=metadata_df['nulls']/metadata_df['count'])
metadata_df.insert(loc=7, column='percent_unique', value=metadata_df['unique']/metadata_df['count'])

metadata_df.to_excel(r'.\data\chicago-dataset-summary.xlsx', index=False)
print("\nData loaded successfully...")
# metadata_df
# Out:
# PROCESSING: CRASHES...
# PROCESSING: VEHICLES...
# PROCESSING: PEOPLE...
#
# Data loaded successfully...

# %%
## PART 4
## Check all samples. If any of them does not exist, regenerate all
sample_size=0.1
sample_data_frames={}

files_found = 0
for _, r in data_files.iterrows():
    files_found += os.path.isfile(r['csv_sample_file'])

if files_found == len(data_files['csv_sample_file']):
    print("All samples found!")
else:
    print(f"Regenerating samples using {sample_size*100:0.0f}% of data...\n")
    
    # Identify common ID's in the sample
    df = data_frames['CRASHES']['CRASH_RECORD_ID'].sample(frac=sample_size)
    df = pd.merge(left=df, right=data_frames['VEHICLES'], on='CRASH_RECORD_ID', how='inner').drop_duplicates(subset=['CRASH_RECORD_ID'])['CRASH_RECORD_ID']
    df = pd.merge(left=df, right=data_frames['PEOPLE'], on='CRASH_RECORD_ID', how='inner').drop_duplicates(subset=['CRASH_RECORD_ID'])['CRASH_RECORD_ID']
    
    # sample!
    for _, r in data_files.iterrows():
        print(f"Writing: {r['csv_sample_file']}")
        sample_data_frames[r['tableName']] = pd.merge(left=df, right=data_frames[r['tableName']], on='CRASH_RECORD_ID', how='inner')
        sample_data_frames[r['tableName']].to_csv(r['csv_sample_file'])
# Out:
# All samples found!

# %%
data_frames['CRASHES'].shape
# Out:
# (823577, 49)

# %%
## PART 5
## Data Reduction
## 1. Drop columns with ~100% nulls
null_cols1 = {'CRASHES': ['WORKERS_PRESENT_I',         'DOORING_I',            'WORK_ZONE_TYPE',
                          'WORK_ZONE_I',               'PHOTOS_TAKEN_I',       'STATEMENTS_TAKEN_I',
                          'NOT_RIGHT_OF_WAY_I',        'CRASH_DATE_EST_I'],
              
              'VEHICLES': ['HAZMAT_REPORT_NO',         'MCS_REPORT_NO',        'HAZMAT_NAME',
                           'TRAILER2_LENGTH',          'WIDE_LOAD_I',          'HAZMAT_PLACARDS_I',
                           'TRAILER2_WIDTH',           'UN_NO',                'IDOT_PERMIT_NO',
                           'HAZMAT_CLASS',             'FIRE_I',               'ILCC_NO',
                           'CCMC_NO',                  'TRAILER1_LENGTH',      'EXCEED_SPEED_LIMIT_I',
                           'TOTAL_VEHICLE_LENGTH',     'TRAILER1_WIDTH',       'AXLE_CNT',
                           'GVWR',                     'USDOT_NO',             'COMMERCIAL_SRC',
                           'HAZMAT_OUT_OF_SERVICE_I',  'MCS_OUT_OF_SERVICE_I', 'MCS_VIO_CAUSE_CRASH_I',
                           'HAZMAT_REPORT_I',          'MCS_REPORT_I',         'HAZMAT_VIO_CAUSE_CRASH_I',
                           'HAZMAT_PRESENT_I',         'LOAD_TYPE',            'CARGO_BODY_TYPE',
                           'VEHICLE_CONFIG',           'CARRIER_CITY',         'CARRIER_STATE',
                           'CARRIER_NAME',             'CMV_ID',               'CMRC_VEH_I',
                           'AREA_00_I',                'TOWED_TO',             'AREA_09_I',
                           'TOWED_BY',                 'AREA_04_I',            'AREA_03_I',
                           'AREA_10_I'],
              
              'PEOPLE': ['CELL_PHONE_USE',             'BAC_RESULT VALUE',     'EMS_RUN_NO',
                         'PEDPEDAL_VISIBILITY',        'PEDPEDAL_LOCATION',    'PEDPEDAL_ACTION']
}

for t in null_cols1:
    data_frames[t].drop(null_cols1[t], axis=1, inplace=True)

## 2. Drop columns with 80%~99% nulls
null_cols2 = {'CRASHES': ['INTERSECTION_RELATED_I',    'LANE_CNT'],
              
              'VEHICLES': ['AREA_99_I',                'AREA_08_I',            'AREA_07_I',
                           'AREA_05_I',                'AREA_06_I',            'AREA_02_I',
                           'AREA_12_I',                'AREA_11_I',            'AREA_01_I'],
              
              'PEOPLE': ['EMS_AGENCY']
}

for t in null_cols2:
    data_frames[t].drop(null_cols2[t], axis=1, inplace=True)

print("Writing stage 1 results...")
for _, r in data_files.iterrows():
    if not os.path.isfile(r['reduced_st1']):
        print(f"NOT FOUND: {r['reduced_st1']}.\nCREATING: {r['reduced_st1']}...", end="")
        data_frames[r['tableName']].to_parquet(r['reduced_st1'], index=False, compression='gzip', engine='auto')
        print("DONE!\n")
    else:
        print(f"FOUND: {r['reduced_st1']}.\nMoving on...\n")

print("Data reduction completed successfully...")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 29
#       4 null_cols1 = {'CRASHES': ['WORKERS_PRESENT_I',         'DOORING_I',            'WORK_ZONE_TYPE',
#       5                           'WORK_ZONE_I',               'PHOTOS_TAKEN_I',       'STATEMENTS_TAKEN_I',
#       6                           'NOT_RIGHT_OF_WAY_I',        'CRASH_DATE_EST_I'],
#    (...)
#      25                          'PEDPEDAL_VISIBILITY',        'PEDPEDAL_LOCATION',    'PEDPEDAL_ACTION']
#      26 }
#      28 for t in null_cols1:
# ---> 29     data_frames[t].drop(null_cols1[t], axis=1, inplace=True)
#      31 # data_frames['VEHICLES'][data_frames['VEHICLES']['UNIT_TYPE']!='DRIVER'].head().T
#      32 # data_frames['VEHICLES'][data_frames['VEHICLES']['UNIT_TYPE']=='BICYCLE']
#      33 # data_frames['VEHICLES'][data_frames['VEHICLES']['UNIT_TYPE'].isnull()].head().T
#      34 cid = 'f59f115cb6eda57e929debe2c17026ca17bce6ad0d9842cdcec64f1779dada0c32925d2209fe9ac280cc57acafb6462896470052d27d63d2eae5c8e7e36fdb06'
#
# File v:\anaconda3\envs\isye6740-cda\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File v:\anaconda3\envs\isye6740-cda\Lib\site-packages\pandas\core\generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File v:\anaconda3\envs\isye6740-cda\Lib\site-packages\pandas\core\generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File v:\anaconda3\envs\isye6740-cda\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['WORKERS_PRESENT_I', 'DOORING_I', 'WORK_ZONE_TYPE', 'WORK_ZONE_I', 'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'NOT_RIGHT_OF_WAY_I', 'CRASH_DATE_EST_I'] not found in axis"

# %%
print("Writing stage 1 results...")
for _, r in data_files.iterrows():
    if not os.path.isfile(r['reduced_st1']):
        print(f"NOT FOUND: {r['reduced_st1']}.\nCREATING: {r['reduced_st1']}...", end="")
        data_frames[r['tableName']].to_parquet(r['reduced_st1'], index=False, compression='gzip', engine='auto')
        print("DONE!\n")
    else:
        print(f"FOUND: {r['reduced_st1']}.\nMoving on...\n")

print("Data reduced successfully...")
# data_frames['VEHICLES'][data_frames['VEHICLES']['UNIT_TYPE']!='DRIVER'].head().T
# data_frames['VEHICLES'][data_frames['VEHICLES']['UNIT_TYPE']=='BICYCLE']
# data_frames['VEHICLES'][data_frames['VEHICLES']['UNIT_TYPE'].isnull()].head().T
cid = 'f59f115cb6eda57e929debe2c17026ca17bce6ad0d9842cdcec64f1779dada0c32925d2209fe9ac280cc57acafb6462896470052d27d63d2eae5c8e7e36fdb06'
data_frames['PEOPLE'][data_frames['PEOPLE']['ZIPCODE'].isnull() == True].head().T
# Out:
# Writing stage 1 results...
# NOT FOUND: .\data\reduced\stage1\chicago-crashes-reduced-st1.parquet.gzip.
# CREATING: .\data\reduced\stage1\chicago-crashes-reduced-st1.parquet.gzip...DONE!
#
# NOT FOUND: .\data\reduced\stage1\chicago-vehicles-reduced-st1.parquet.gzip.
# CREATING: .\data\reduced\stage1\chicago-vehicles-reduced-st1.parquet.gzip...DONE!
#
# NOT FOUND: .\data\reduced\stage1\chicago-people-reduced-st1.parquet.gzip.
# CREATING: .\data\reduced\stage1\chicago-people-reduced-st1.parquet.gzip...DONE!
#
#
# Data reduced successfully...
#                                                                        2  \
# PERSON_ID                                                         O10018
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        71162af7bf22799b776547132ebf134b5b438dcf3dac6b...
# VEHICLE_ID                                                        9579.0
# CRASH_DATE                                        11/01/2015 05:00:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                            NONE
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# DRIVER_ACTION                                           IMPROPER BACKING
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# BAC_RESULT                                              TEST NOT OFFERED
#
#                                                                        3  \
# PERSON_ID                                                         O10038
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...
# VEHICLE_ID                                                        9598.0
# CRASH_DATE                                        11/01/2015 08:00:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                         UNKNOWN
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# BAC_RESULT                                              TEST NOT OFFERED
#
#                                                                        4  \
# PERSON_ID                                                         O10039
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...
# VEHICLE_ID                                                        9600.0
# CRASH_DATE                                        11/01/2015 10:15:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                         UNKNOWN
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# BAC_RESULT                                              TEST NOT OFFERED
#
#                                                                        5  \
# PERSON_ID                                                         O10041
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        dd1bce4bd6d0be4c247714dcabab44e6563c62b913229b...
# VEHICLE_ID                                                        9601.0
# CRASH_DATE                                        11/01/2015 11:00:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                            NONE
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# BAC_RESULT                                              TEST NOT OFFERED
#
#                                                                        6
# PERSON_ID                                                         O10062
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        4bd2ee6bb306902b99a9c2ae55cf4fcffec00879e39759...
# VEHICLE_ID                                                        9621.0
# CRASH_DATE                                        11/01/2015 12:30:00 PM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                 XX
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                            NONE
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# BAC_RESULT                                              TEST NOT OFFERED

# %%
## Part 3: EDA
data_frames['CRASHES'].describe(include='all').T
# Out:
#                                   count  unique  \
# CRASH_RECORD_ID                  823577  823577
# CRASH_DATE                       823577  540963
# POSTED_SPEED_LIMIT             823577.0     NaN
# TRAFFIC_CONTROL_DEVICE           823577      19
# DEVICE_CONDITION                 823577       8
# WEATHER_CONDITION                823577      12
# LIGHTING_CONDITION               823577       6
# FIRST_CRASH_TYPE                 823577      18
# TRAFFICWAY_TYPE                  823577      20
# LANE_CNT                       199010.0     NaN
# ALIGNMENT                        823577       6
# ROADWAY_SURFACE_COND             823577       7
# ROAD_DEFECT                      823577       7
# REPORT_TYPE                      799010       3
# CRASH_TYPE                       823577       2
# INTERSECTION_RELATED_I           188845       2
# HIT_AND_RUN_I                    257855       2
# DAMAGE                           823577       3
# DATE_POLICE_NOTIFIED             823577  625044
# PRIM_CONTRIBUTORY_CAUSE          823577      40
# SEC_CONTRIBUTORY_CAUSE           823577      40
# STREET_NO                      823577.0     NaN
# STREET_DIRECTION                 823573       4
# STREET_NAME                      823576    1641
# BEAT_OF_OCCURRENCE             823572.0     NaN
# NUM_UNITS                      823577.0     NaN
# MOST_SEVERE_INJURY               821765       5
# INJURIES_TOTAL                 821777.0     NaN
# INJURIES_FATAL                 821777.0     NaN
# INJURIES_INCAPACITATING        821777.0     NaN
# INJURIES_NON_INCAPACITATING    821777.0     NaN
# INJURIES_REPORTED_NOT_EVIDENT  821777.0     NaN
# INJURIES_NO_INDICATION         821777.0     NaN
# INJURIES_UNKNOWN               821777.0     NaN
# CRASH_HOUR                     823577.0     NaN
# CRASH_DAY_OF_WEEK              823577.0     NaN
# CRASH_MONTH                    823577.0     NaN
# LATITUDE                       817890.0     NaN
# LONGITUDE                      817890.0     NaN
# LOCATION                         817890  301570
# Boundaries - ZIP Codes         817498.0     NaN
#
#                                                                              top  \
# CRASH_RECORD_ID                1e9318e69bbdc24db5137569e760a6a8feeb1ccce86e88...
# CRASH_DATE                                                12/29/2020 05:00:00 PM
# POSTED_SPEED_LIMIT                                                           NaN
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                            PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# LANE_CNT                                                                     NaN
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                         Y
# HIT_AND_RUN_I                                                                  Y
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      12/01/2023 05:30:00 PM
# PRIM_CONTRIBUTORY_CAUSE                                      UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                    NaN
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          WESTERN AVE
# BEAT_OF_OCCURRENCE                                                           NaN
# NUM_UNITS                                                                    NaN
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               NaN
# INJURIES_FATAL                                                               NaN
# INJURIES_INCAPACITATING                                                      NaN
# INJURIES_NON_INCAPACITATING                                                  NaN
# INJURIES_REPORTED_NOT_EVIDENT                                                NaN
# INJURIES_NO_INDICATION                                                       NaN
# INJURIES_UNKNOWN                                                             NaN
# CRASH_HOUR                                                                   NaN
# CRASH_DAY_OF_WEEK                                                            NaN
# CRASH_MONTH                                                                  NaN
# LATITUDE                                                                     NaN
# LONGITUDE                                                                    NaN
# LOCATION                                POINT (-87.905309125103 41.976201139024)
# Boundaries - ZIP Codes                                                       NaN
#
#                                  freq         mean          std        min  \
# CRASH_RECORD_ID                     1          NaN          NaN        NaN
# CRASH_DATE                         30          NaN          NaN        NaN
# POSTED_SPEED_LIMIT                NaN    28.407103     6.161772        0.0
# TRAFFIC_CONTROL_DEVICE         468070          NaN          NaN        NaN
# DEVICE_CONDITION               473497          NaN          NaN        NaN
# WEATHER_CONDITION              645355          NaN          NaN        NaN
# LIGHTING_CONDITION             526779          NaN          NaN        NaN
# FIRST_CRASH_TYPE               191357          NaN          NaN        NaN
# TRAFFICWAY_TYPE                357372          NaN          NaN        NaN
# LANE_CNT                          NaN    13.330109  2961.593711        0.0
# ALIGNMENT                      803628          NaN          NaN        NaN
# ROADWAY_SURFACE_COND           606970          NaN          NaN        NaN
# ROAD_DEFECT                    661556          NaN          NaN        NaN
# REPORT_TYPE                    450630          NaN          NaN        NaN
# CRASH_TYPE                     603496          NaN          NaN        NaN
# INTERSECTION_RELATED_I         179870          NaN          NaN        NaN
# HIT_AND_RUN_I                  246789          NaN          NaN        NaN
# DAMAGE                         511909          NaN          NaN        NaN
# DATE_POLICE_NOTIFIED               12          NaN          NaN        NaN
# PRIM_CONTRIBUTORY_CAUSE        320722          NaN          NaN        NaN
# SEC_CONTRIBUTORY_CAUSE         338416          NaN          NaN        NaN
# STREET_NO                         NaN  3689.666761  2886.071704        0.0
# STREET_DIRECTION               294462          NaN          NaN        NaN
# STREET_NAME                     22476          NaN          NaN        NaN
# BEAT_OF_OCCURRENCE                NaN   1243.92634   705.191951      111.0
# NUM_UNITS                         NaN     2.034946     0.452914        1.0
# MOST_SEVERE_INJURY             708310          NaN          NaN        NaN
# INJURIES_TOTAL                    NaN     0.190144      0.56634        0.0
# INJURIES_FATAL                    NaN     0.001186     0.037276        0.0
# INJURIES_INCAPACITATING           NaN     0.019862     0.164849        0.0
# INJURIES_NON_INCAPACITATING       NaN     0.107197     0.422515        0.0
# INJURIES_REPORTED_NOT_EVIDENT     NaN     0.061899     0.319582        0.0
# INJURIES_NO_INDICATION            NaN     2.003142     1.157168        0.0
# INJURIES_UNKNOWN                  NaN          0.0          0.0        0.0
# CRASH_HOUR                        NaN    13.198426     5.570631        0.0
# CRASH_DAY_OF_WEEK                 NaN     4.123085     1.980812        1.0
# CRASH_MONTH                       NaN     6.634803     3.449507        1.0
# LATITUDE                          NaN    41.854907     0.335236        0.0
# LONGITUDE                         NaN   -87.673594     0.681191 -87.936193
# LOCATION                         1312          NaN          NaN        NaN
# Boundaries - ZIP Codes            NaN    32.214843    19.204799        1.0
#
#                                      25%        50%        75%        max
# CRASH_RECORD_ID                      NaN        NaN        NaN        NaN
# CRASH_DATE                           NaN        NaN        NaN        NaN
# POSTED_SPEED_LIMIT                  30.0       30.0       30.0       99.0
# TRAFFIC_CONTROL_DEVICE               NaN        NaN        NaN        NaN
# DEVICE_CONDITION                     NaN        NaN        NaN        NaN
# WEATHER_CONDITION                    NaN        NaN        NaN        NaN
# LIGHTING_CONDITION                   NaN        NaN        NaN        NaN
# FIRST_CRASH_TYPE                     NaN        NaN        NaN        NaN
# TRAFFICWAY_TYPE                      NaN        NaN        NaN        NaN
# LANE_CNT                             2.0        2.0        4.0  1191625.0
# ALIGNMENT                            NaN        NaN        NaN        NaN
# ROADWAY_SURFACE_COND                 NaN        NaN        NaN        NaN
# ROAD_DEFECT                          NaN        NaN        NaN        NaN
# REPORT_TYPE                          NaN        NaN        NaN        NaN
# CRASH_TYPE                           NaN        NaN        NaN        NaN
# INTERSECTION_RELATED_I               NaN        NaN        NaN        NaN
# HIT_AND_RUN_I                        NaN        NaN        NaN        NaN
# DAMAGE                               NaN        NaN        NaN        NaN
# DATE_POLICE_NOTIFIED                 NaN        NaN        NaN        NaN
# PRIM_CONTRIBUTORY_CAUSE              NaN        NaN        NaN        NaN
# SEC_CONTRIBUTORY_CAUSE               NaN        NaN        NaN        NaN
# STREET_NO                         1250.0     3201.0     5600.0   451100.0
# STREET_DIRECTION                     NaN        NaN        NaN        NaN
# STREET_NAME                          NaN        NaN        NaN        NaN
# BEAT_OF_OCCURRENCE                 714.0     1212.0     1822.0     6100.0
# NUM_UNITS                            2.0        2.0        2.0       18.0
# MOST_SEVERE_INJURY                   NaN        NaN        NaN        NaN
# INJURIES_TOTAL                       0.0        0.0        0.0       21.0
# INJURIES_FATAL                       0.0        0.0        0.0        4.0
# INJURIES_INCAPACITATING              0.0        0.0        0.0       10.0
# INJURIES_NON_INCAPACITATING          0.0        0.0        0.0       21.0
# INJURIES_REPORTED_NOT_EVIDENT        0.0        0.0        0.0       15.0
# INJURIES_NO_INDICATION               1.0        2.0        2.0       61.0
# INJURIES_UNKNOWN                     0.0        0.0        0.0        0.0
# CRASH_HOUR                           9.0       14.0       17.0       23.0
# CRASH_DAY_OF_WEEK                    2.0        4.0        6.0        7.0
# CRASH_MONTH                          4.0        7.0       10.0       12.0
# LATITUDE                       41.782557  41.874832   41.92441   42.02278
# LONGITUDE                     -87.721764 -87.674195 -87.633431        0.0
# LOCATION                             NaN        NaN        NaN        NaN
# Boundaries - ZIP Codes              15.0       32.0       51.0       61.0

# %%
data_frames['PEOPLE'][data_frames['PEOPLE']['AGE'].isnull()].head().T
# Out:
#                                                                        2  \
# PERSON_ID                                                         O10018
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        71162af7bf22799b776547132ebf134b5b438dcf3dac6b...
# VEHICLE_ID                                                        9579.0
# CRASH_DATE                                        11/01/2015 05:00:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                            NONE
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# EMS_AGENCY                                                           NaN
# EMS_RUN_NO                                                           NaN
# DRIVER_ACTION                                           IMPROPER BACKING
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# PEDPEDAL_ACTION                                                      NaN
# PEDPEDAL_VISIBILITY                                                  NaN
# PEDPEDAL_LOCATION                                                    NaN
# BAC_RESULT                                              TEST NOT OFFERED
# BAC_RESULT VALUE                                                     NaN
# CELL_PHONE_USE                                                       NaN
#
#                                                                        3  \
# PERSON_ID                                                         O10038
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...
# VEHICLE_ID                                                        9598.0
# CRASH_DATE                                        11/01/2015 08:00:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                         UNKNOWN
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# EMS_AGENCY                                                           NaN
# EMS_RUN_NO                                                           NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# PEDPEDAL_ACTION                                                      NaN
# PEDPEDAL_VISIBILITY                                                  NaN
# PEDPEDAL_LOCATION                                                    NaN
# BAC_RESULT                                              TEST NOT OFFERED
# BAC_RESULT VALUE                                                     NaN
# CELL_PHONE_USE                                                       NaN
#
#                                                                        4  \
# PERSON_ID                                                         O10039
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...
# VEHICLE_ID                                                        9600.0
# CRASH_DATE                                        11/01/2015 10:15:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                         UNKNOWN
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# EMS_AGENCY                                                           NaN
# EMS_RUN_NO                                                           NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# PEDPEDAL_ACTION                                                      NaN
# PEDPEDAL_VISIBILITY                                                  NaN
# PEDPEDAL_LOCATION                                                    NaN
# BAC_RESULT                                              TEST NOT OFFERED
# BAC_RESULT VALUE                                                     NaN
# CELL_PHONE_USE                                                       NaN
#
#                                                                        5  \
# PERSON_ID                                                         O10041
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        dd1bce4bd6d0be4c247714dcabab44e6563c62b913229b...
# VEHICLE_ID                                                        9601.0
# CRASH_DATE                                        11/01/2015 11:00:00 AM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                NaN
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                            NONE
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# EMS_AGENCY                                                           NaN
# EMS_RUN_NO                                                           NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# PEDPEDAL_ACTION                                                      NaN
# PEDPEDAL_VISIBILITY                                                  NaN
# PEDPEDAL_LOCATION                                                    NaN
# BAC_RESULT                                              TEST NOT OFFERED
# BAC_RESULT VALUE                                                     NaN
# CELL_PHONE_USE                                                       NaN
#
#                                                                        6
# PERSON_ID                                                         O10062
# PERSON_TYPE                                                       DRIVER
# CRASH_RECORD_ID        4bd2ee6bb306902b99a9c2ae55cf4fcffec00879e39759...
# VEHICLE_ID                                                        9621.0
# CRASH_DATE                                        11/01/2015 12:30:00 PM
# SEAT_NO                                                              NaN
# CITY                                                                 NaN
# STATE                                                                NaN
# ZIPCODE                                                              NaN
# SEX                                                                    X
# AGE                                                                  NaN
# DRIVERS_LICENSE_STATE                                                 XX
# DRIVERS_LICENSE_CLASS                                                NaN
# SAFETY_EQUIPMENT                                           USAGE UNKNOWN
# AIRBAG_DEPLOYED                                       DEPLOYMENT UNKNOWN
# EJECTION                                                            NONE
# INJURY_CLASSIFICATION                            NO INDICATION OF INJURY
# HOSPITAL                                                             NaN
# EMS_AGENCY                                                           NaN
# EMS_RUN_NO                                                           NaN
# DRIVER_ACTION                                                    UNKNOWN
# DRIVER_VISION                                                    UNKNOWN
# PHYSICAL_CONDITION                                               UNKNOWN
# PEDPEDAL_ACTION                                                      NaN
# PEDPEDAL_VISIBILITY                                                  NaN
# PEDPEDAL_LOCATION                                                    NaN
# BAC_RESULT                                              TEST NOT OFFERED
# BAC_RESULT VALUE                                                     NaN
# CELL_PHONE_USE                                                       NaN
